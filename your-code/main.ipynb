# %% [markdown]
# # Antes de empezar:
#
#     Lee el archivo README.md
#     Comenta todo lo que puedas y utiliza los recursos (archivo README.md)
#     ¡Feliz aprendizaje!

# %% [markdown]
# En este ejercicio, generaremos números aleatorios a partir de las disribuciones continuas que aprendimos en la lección. Hay dos formas de generar números aleatorios:
#
# 1. Usando la librería numpy
# 1. Usando la librería Scipy
#
# Utiliza cualquiera de las dos librerías o ambas en este ejercicio.

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import math
import seaborn as sns

# %% [markdown]
# ## Distribución Uniforme
#
# Para generar números aleatorios uniformes entre dos valores dados usando scipy, podemos usar el siguiente código o el código que hemos
# discutido en clase:

# %%
a = 0 
b = 1
size = 1000 
uniform_data_np = np.random.uniform(a, b, size)

sns.histplot(uniform_data_np, bins=30)
plt.title('Distribución')
plt.xlabel('number')
plt.ylabel('count')
plt.show()

# %% [markdown]
# **Tarea:**
#
# 1. Basándote en el código anterior, escribe una función que genere números aleatorios uniformemente distribuidos. Hay varios requisitos para tu función:
#     * Debe aceptar 3 parámetros:
#         * `bottom` - el límite inferior de los números generados
#         * `ceiling` - el límite superior de los números generados
#         * `count` - cuántos números generar
#     * Debe devolver una matriz de números aleatorios distribuidos uniformemente
#
# 2. Llama a tu función con 2 conjuntos de parámetros a continuación:
#     * bottom=10, ceiling=15, count=100
#     * bottom=10, ceiling=60, count=1,000
#
# 3. Traza las distribuciones uniformes generadas anteriormente utilizando histogramas, donde el eje x es el valor y el eje y es el recuento. Que el número de intervalos del histograma sea 10.
#
# El resultado debe ser como el siguiente:
#
# ![image.png](attachment:image.png)

# %%
def generate_uniform_random(bottom, ceiling, count):
    return np.random.uniform(bottom, ceiling, count)

# %%
uniform_data_1 = generate_uniform_random(10, 15, 100)
uniform_data_2 = generate_uniform_random(10, 60, 1000)

# %%
plt.subplot(1, 2, 1)
plt.hist(uniform_data_1, bins=10, edgecolor='black')
plt.title('Uniform Distribution: 10 to 15, Count: 100')
plt.xlabel('Value')
plt.ylabel('Count')

# %% [markdown]
# How are the two distributions different?

# %%
plt.subplot(1, 2, 2)
plt.hist(uniform_data_2, bins=10, edgecolor='black')
plt.title('Uniform Distribution: 10 to 60, Count: 1000')
plt.xlabel('Value')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %% [markdown]
# ## Distribución Normal
#
# 1. De la misma manera en el reto de Distribución Uniforme, escriba una función que genere números aleatorios distribuidos normalmente.
# 1. Genera 1.000 números distribuidos normalmente con media de 10 y desviación típica de 1
# 1. Genera 1.000 números distribuidos normalmente con una media de 10 y una desviación típica de 50
# 2. Representa gráficamente las distribuciones de los datos generados.
#
# Resultado esperado:
#
# ![image.png](attachment:image.png)

# %%
from scipy.stats import norm

# %%
def generate_normal_random(mean, std_dev, count):
    return np.random.normal(mean, std_dev, count)

# Generate numbers with the specified parameters
normal_data_1 = generate_normal_random(10, 1, 1000)
normal_data_2 = generate_normal_random(10, 50, 1000)

# %%
plt.figure(figsize=(12, 6))

# Histogram for the first set (mean=10, std_dev=1)
plt.subplot(1, 2, 1)
plt.hist(normal_data_1, bins=30, edgecolor='black')
plt.title('Normal Distribution: mean=10, std_dev=1')
plt.xlabel('Value')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
plt.subplot(1, 2, 2)
plt.hist(normal_data_2, bins=30, edgecolor='black')
plt.title('Normal Distribution: mean=10, std_dev=50')
plt.xlabel('Value')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
# your code here

# %% [markdown]
# How are the two distributions different?

# %% [raw]
# Your answer here

# %% [markdown]
# ## Distribución Normal de Datos Reales
#
# En este reto vamos a echar un vistazo a los datos reales. Utilizaremos el archivo vehicles.csv para este ejercicio

# %%
vehicles = pd.read_csv('vehicles.csv')
vehicles.head()
# Out:
#                Make                Model  Year  Engine Displacement  \
# 0        AM General    DJ Po Vehicle 2WD  1984                  2.5
# 1        AM General     FJ8c Post Office  1984                  4.2
# 2        AM General  Post Office DJ5 2WD  1985                  2.5
# 3        AM General  Post Office DJ8 2WD  1985                  4.2
# 4  ASC Incorporated                  GNX  1987                  3.8
#
#    Cylinders     Transmission        Drivetrain                Vehicle Class  \
# 0        4.0  Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD
# 1        6.0  Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD
# 2        4.0  Automatic 3-spd  Rear-Wheel Drive  Special Purpose Vehicle 2WD
# 3        6.0  Automatic 3-spd  Rear-Wheel Drive  Special Purpose Vehicle 2WD
# 4        6.0  Automatic 4-spd  Rear-Wheel Drive                 Midsize Cars
#
#   Fuel Type  Fuel Barrels/Year  City MPG  Highway MPG  Combined MPG  \
# 0   Regular          19.388824        18           17            17
# 1   Regular          25.354615        13           13            13
# 2   Regular          20.600625        16           17            16
# 3   Regular          25.354615        13           13            13
# 4   Premium          20.600625        14           21            16
#
#    CO2 Emission Grams/Mile  Fuel Cost/Year
# 0               522.764706            1950
# 1               683.615385            2550
# 2               555.437500            2100
# 3               683.615385            2550
# 4               555.437500            2550

# %% [markdown]
# Primero importa vehicles.csv.
# A continuación, traza los histogramas de las siguientes variables:
#
# 1. Barriles de combustible/año

# %%
fuelperyear = vehicles['Fuel Barrels/Year']

# %%
plt.hist(fuelperyear, bins = 30)
plt.title('Histogram of Normally Distributed Data')
plt.xlabel('Value')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %% [markdown]
# 2. Emisiones de CO2 Gramos/Milla

# %%
grampermile = vehicles['CO2 Emission Grams/Mile']

# %%
plt.hist(grampermile, bins = 30)
plt.title('Histogram of Normally Distributed Data')
plt.xlabel('Value')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %% [markdown]
# 3. MPG combinado

# %%
plt.hist(vehicles["Combined MPG"], bins = 30)
# Out:
# (array([2.600e+01, 1.710e+02, 4.410e+02, 1.996e+03, 4.188e+03, 2.315e+03,
#         5.979e+03, 6.375e+03, 3.158e+03, 4.041e+03, 1.546e+03, 2.345e+03,
#         1.331e+03, 4.530e+02, 6.320e+02, 3.450e+02, 1.620e+02, 1.290e+02,
#         8.400e+01, 2.300e+01, 1.030e+02, 3.700e+01, 1.200e+01, 1.600e+01,
#         1.600e+01, 2.000e+00, 1.500e+01, 5.000e+00, 4.000e+00, 2.000e+00]),
#  array([ 7.        ,  8.63333333, 10.26666667, 11.9       , 13.53333333,
#         15.16666667, 16.8       , 18.43333333, 20.06666667, 21.7       ,
#         23.33333333, 24.96666667, 26.6       , 28.23333333, 29.86666667,
#         31.5       , 33.13333333, 34.76666667, 36.4       , 38.03333333,
#         39.66666667, 41.3       , 42.93333333, 44.56666667, 46.2       ,
#         47.83333333, 49.46666667, 51.1       , 52.73333333, 54.36666667,
#         56.        ]),
#  <BarContainer object of 30 artists>)

# %%
plt.hist(vehicles["Combined MPG"], bins = 60)
# Out:
# (array([5.000e+00, 2.100e+01, 4.000e+01, 1.310e+02, 4.410e+02, 0.000e+00,
#         7.410e+02, 1.255e+03, 1.947e+03, 2.241e+03, 0.000e+00, 2.315e+03,
#         2.420e+03, 3.559e+03, 3.282e+03, 3.093e+03, 0.000e+00, 3.158e+03,
#         2.247e+03, 1.794e+03, 1.546e+03, 0.000e+00, 1.278e+03, 1.067e+03,
#         6.920e+02, 6.390e+02, 4.530e+02, 0.000e+00, 3.710e+02, 2.610e+02,
#         1.690e+02, 1.760e+02, 0.000e+00, 1.620e+02, 7.100e+01, 5.800e+01,
#         4.100e+01, 4.300e+01, 0.000e+00, 2.300e+01, 6.500e+01, 3.800e+01,
#         3.700e+01, 0.000e+00, 7.000e+00, 5.000e+00, 5.000e+00, 1.100e+01,
#         1.600e+01, 0.000e+00, 2.000e+00, 0.000e+00, 1.500e+01, 0.000e+00,
#         0.000e+00, 5.000e+00, 4.000e+00, 0.000e+00, 0.000e+00, 2.000e+00]),
#         31.5       , 32.04444444, 32.58888889, 33.13333333, 33.67777778,
#         34.22222222, 34.76666667, 35.31111111, 35.85555556, 36.4       ,
#         36.94444444, 37.48888889, 38.03333333, 38.57777778, 39.12222222,
#         39.66666667, 40.21111111, 40.75555556, 41.3       , 41.84444444,
#         42.38888889, 42.93333333, 43.47777778, 44.02222222, 44.56666667,
#         45.11111111, 45.65555556, 46.2       , 46.74444444, 47.28888889,
#         47.83333333, 48.37777778, 48.92222222, 49.46666667, 50.01111111,
#         50.55555556, 51.1       , 51.64444444, 52.18888889, 52.73333333,
#         53.27777778, 53.82222222, 54.36666667, 54.91111111, 55.45555556,
#         56.        ]),
#  <BarContainer object of 90 artists>)

# %% [markdown]
# ¿Cuál o cuáles de las variables tienen una distribución casi normal? ¿Cómo lo sabes?

# %%
def plot_histogram(data,title, bins=30 ):
    sns.histplot(data, bins=bins, kde=False, stat='density')
    
    mean = np.mean(data)
    std_dev = np.std(data)
    x = np.linspace(min(data), max(data), 100)
    pdf = norm.pdf(x, mean, std_dev)
    plt.plot(x, pdf, 'r', label='Distribución Normal')
    plt.title(title)
    plt.xlabel('Valor')
    plt.ylabel('Densidad')
    plt.legend()
    plt.show()

# %%
plot_histogram(fuelperyear, "fuelperyear", 30)

# %%
plot_histogram(grampermile, 'mile per hour', 90)

# %%
plot_histogram(vehicles['Combined MPG'], 'MPG', 60)

# %% [markdown]
# Ninguno de ellos está normalmente ditribuido.

# %% [markdown]
# ## Distribución Exponencial

# %% [markdown]
# 1. Utilizando `numpy.random.exponential`, crea una función que devuelva una lista de números distribuidos exponencialmente con la media de 10.
#
# 1. Utiliza la función para generar dos secuencias de números de tamaño 10 y 100.
#
# 1. 2. Traza las distribuciones como histogramas con el número de bins como 100.
#
# El resultado debe ser como el siguiente:
#
# ![image.png](attachment:image.png)

# %%
import numpy as np
import matplotlib.pyplot as plt

def generate_exponential_data(size, scale=10):

    return np.random.exponential(scale, size)

data_10 = generate_exponential_data(10)
data_100 = generate_exponential_data(100)

fig, axs = plt.subplots(1, 2, figsize=(14, 6))

axs[0].hist(data_10, bins=100, color='blue', alpha=0.7)
axs[0].set_title('Distribución Exponencial - Tamaño 10')
axs[0].set_xlabel('Valor')
axs[0].set_ylabel('Frecuencia')

axs[1].hist(data_100, bins=100, color='green', alpha=0.7)
axs[1].set_title('Distribución Exponencial - Tamaño 100')
axs[1].set_xlabel('Valor')
axs[1].set_ylabel('Frecuencia')

plt.tight_layout()
plt.show()

# %% [markdown]
# ¿En qué se diferencian ambas distribuciones?

# %% [markdown]
# La media cambia, por lo que la distribución también cambia.

# %% [markdown]
# ## Distribución Exponencial de datos reales
#
# Supongamos que el tiempo que uno pasa en un banco se distribuye exponencialmente con media de 10 minutos (es decir, λ = 1/10). ¿Cuál es la probabilidad de que un cliente pase menos de quince minutos en el banco?
#
# Escribe un código en python para resolver este problema

# %%
lambda_param = 1 / 10

# %%
time_limit = 15

# Calcular la probabilidad usando la CDF de la distribución exponencial
less_than_15 = 1 - np.exp(-lambda_param * time_limit)

# %% [markdown]
# ¿Cuál es la probabilidad de que el cliente pase más de 15 minutos?

# %%
1-less_than_15
# Out:
# 0.2231301601484298
